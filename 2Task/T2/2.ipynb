# %%
import numpy as np
from LinearRegr import CategoricalRegression
# Out:
# ======================================================================
# КОЭФФИЦИЕНТЫ (СРЕДНИЕ ПО ГРУППАМ)
# ======================================================================
#   Группа 1: 84.0000
#   Группа 2: 85.5000
#   Группа 3: 87.8182
#   Группа 4: 90.0000
#   Группа 5: 91.0000
#
# RSS = 23.1364
# MSE = 1.1568
# df_residual = 20
#
# ======================================================================
# ПОПАРНЫЕ СРАВНЕНИЯ (Бонферрони-Холм, α = 0.05)
# ======================================================================
#
# Ранг   Группы       Разница    t          p-value    α скорр.     Значимо?
# ----------------------------------------------------------------------
# 1      1 vs 5     -7.0000    6.5083     0.0000     0.0050       ✓ ДА
# 2      2 vs 4     -4.5000    6.4817     0.0000     0.0056       ✓ ДА
# 3      1 vs 4     -6.0000    6.4415     0.0000     0.0063       ✓ ДА
# 4      2 vs 5     -5.5000    6.2629     0.0000     0.0071       ✓ ДА
# 5      1 vs 3     -3.8182    4.6181     0.0002     0.0083       ✓ ДА
# 6      2 vs 3     -2.3182    4.2468     0.0004     0.0100       ✓ ДА
# 7      3 vs 5     -3.1818    3.8484     0.0010     0.0125       ✓ ДА
# 8      3 vs 4     -2.1818    3.4743     0.0024     0.0167       ✓ ДА
# 9      1 vs 2     -1.5000    1.7081     0.1031     0.0250       ✗ НЕТ
# 10     4 vs 5     -1.0000    1.0736     0.2958     0.0500       ✗ НЕТ
#
# ======================================================================
# ВЫВОДЫ:
# ======================================================================
#   Группы 1 и 5 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0000 < 0.0050)
#   Группы 2 и 4 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0000 < 0.0056)
#   Группы 1 и 4 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0000 < 0.0063)
#   Группы 2 и 5 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0000 < 0.0071)
#   Группы 1 и 3 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0002 < 0.0083)
#   Группы 2 и 3 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0004 < 0.0100)
#   Группы 3 и 5 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0010 < 0.0125)
#   Группы 3 и 4 СТАТИСТИЧЕСКИ РАЗЛИЧАЮТСЯ (p=0.0024 < 0.0167)
#   Группы 1 и 2 НЕ РАЗЛИЧАЮТСЯ (p=0.1031 >= 0.0250)
#   Группы 4 и 5 НЕ РАЗЛИЧАЮТСЯ (p=0.2958 >= 0.0500)

# %%
category = {
    1: [83, 85], 
    2: [84, 85, 85, 86, 86, 87], 
    3: [86, 87, 87, 87, 88, 88, 88, 88, 88, 89, 90], 
    4: [89, 90, 90, 91],
    5: [90, 92]
}

# %%
model = CategoricalRegression(category=category)
coef = model.get_coefficients()
print(f'\nArray of coef:\n{np.array2string(coef, precision=2, floatmode="fixed")}')
# Out:
# Array of coef:
# [84.00 85.50 87.82 90.00 91.00]

# %%
model = CategoricalRegression(category)

results = model.compare(alpha=0.05)

print("\nПопарные сравнения:")
print(f'{">>>":<6} {"Группы":<12} {"Разница":<10} {"t":<10} {"p-value":<10} {"α скорр.":<12} {"Значимо?":<12}')
print('-' * 70)
for r in results:
    print(f'{r["rank"]:<6} '
          f'{r["cat1"]} vs {r["cat2"]:<5} '
          f'{r["diff"]:<10.4f} '
          f'{r["t_stat"]:<10.4f} '
          f'{r["p_value"]:<10.4f} '
          f'{r["adjusted_alpha"]:<12.4f} '
          f'{"ДА" if r["significant"] else "НЕТ":<12}')
# Out:
# Попарные сравнения:
# >>>    Группы       Разница    t          p-value    α скорр.     Значимо?
# ----------------------------------------------------------------------
# 1      1 vs 5     -7.0000    6.5083     0.0000     0.0050       ДА
# 2      2 vs 4     -4.5000    6.4817     0.0000     0.0056       ДА
# 3      1 vs 4     -6.0000    6.4415     0.0000     0.0063       ДА
# 4      2 vs 5     -5.5000    6.2629     0.0000     0.0071       ДА
# 5      1 vs 3     -3.8182    4.6181     0.0002     0.0083       ДА
# 6      2 vs 3     -2.3182    4.2468     0.0004     0.0100       ДА
# 7      3 vs 5     -3.1818    3.8484     0.0010     0.0125       ДА
# 8      3 vs 4     -2.1818    3.4743     0.0024     0.0167       ДА
# 9      1 vs 2     -1.5000    1.7081     0.1031     0.0250       НЕТ
# 10     4 vs 5     -1.0000    1.0736     0.2958     0.0500       НЕТ
